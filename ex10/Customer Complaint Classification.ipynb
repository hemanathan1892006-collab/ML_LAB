# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
dataset = pd.read_csv("consumer_complaints record.csv")
print(dataset.shape)
# Out:
# (40, 2)

# %%
dataset.head()
# Out:
#                                       complaint_text         category
# 0  I was charged an incorrect amount from my bank...          Banking
# 1                    I cannot access my bank account          Banking
# 2           There is a problem with my bank transfer          Banking
# 3                    My account balance is incorrect          Banking
# 4      The ATM charged me but I did not receive cash  Cash Withdrawal

# %%
tfidf = TfidfVectorizer(stop_words='english', max_features=5000)

X_train = tfidf.fit_transform(X_train)
X_test = tfidf.transform(X_test)

print(X_train.shape)
# Out:
# (32, 59)

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# ['Mortgage' 'Student Loan' 'Banking' 'Banking' 'Cash Withdrawal'
#  'Prepaid Card' 'Student Loan' 'Credit Card']

# %%
print("Accuracy is")
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy is
# 0.25

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#         Banking       0.00      0.00      0.00         0
# Cash Withdrawal       1.00      1.00      1.00         1
#     Credit Card       0.00      0.00      0.00         0
# Debt Collection       0.00      0.00      0.00         2
#           Fraud       0.00      0.00      0.00         2
#            Loan       0.00      0.00      0.00         2
#        Mortgage       0.00      0.00      0.00         0
#    Prepaid Card       0.00      0.00      0.00         0
#    Student Loan       0.50      1.00      0.67         1
#
#        accuracy                           0.25         8
#       macro avg       0.17      0.22      0.19         8
#    weighted avg       0.19      0.25      0.21         8
# ...

# %%
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=classifier.classes_,
            yticklabels=classifier.classes_)

plt.xlabel("Predicted Category")
plt.ylabel("Actual Category")
plt.title("Confusion Matrix")
plt.show()

# %%
new_complaint = ["I was charged an incorrect amount from my bank account"]

new_vec = tfidf.transform(new_complaint)

predicted = classifier.predict(new_vec)

print("Predicted Category:", predicted[0])
# Out:
# Predicted Category: Banking
